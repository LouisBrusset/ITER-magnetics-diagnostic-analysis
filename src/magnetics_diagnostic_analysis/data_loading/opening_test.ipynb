# %%
import xarray as xr
import numpy as np
from pathlib import Path

# %%
# Path to the NetCDF file
DATA_PATH = Path().absolute().parent / "data/train.nc"

# %%
ds = xr.open_dataset(DATA_PATH)
ds.load()
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:                                   (shot_id: 30, time: 62282,
#                                                b_field_pol_probe_ccbv_channel: 40,
#                                                b_field_pol_probe_obr_channel: 18,
#                                                b_field_pol_probe_obv_channel: 18,
#                                                b_field_tor_probe_saddle_field_channel: 12,
#                                                b_field_tor_probe_saddle_voltage_channel: 12,
#                                                flux_loop_channel: 15,
#                                                dalpha_channel: 3, channel: 14,
#                                                b_field_pol_probe_cc_channel: 5,
#                                                b_field_pol_probe_omv_channel: 3,
#                                                b_field_tor_probe_cc_channel: 3,
#                                                bes_channel: 32)
# Coordinates: (12/14)
#   * time                                      (time) float64 498kB -0.1056 .....
#   * b_field_pol_probe_ccbv_channel            (b_field_pol_probe_ccbv_channel) <U10 2kB ...
#   * b_field_pol_probe_obr_channel             (b_field_pol_probe_obr_channel) <U9 648B ...
#   * b_field_pol_probe_obv_channel             (b_field_pol_probe_obv_channel) <U9 648B ...
#   * b_field_tor_probe_saddle_field_channel    (b_field_tor_probe_saddle_field_channel) <U11 528B ...
#   * b_field_tor_probe_saddle_voltage_channel  (b_field_tor_probe_saddle_voltage_channel) <U15 720B ...
#     ...                                        ...
#   * channel                                   (channel) <U21 1kB '/xdc/pf/f/p...
#   * shot_id                                   (shot_id) int64 240B 28752 ... ...
#   * b_field_pol_probe_cc_channel              (b_field_pol_probe_cc_channel) <U13 260B ...
#   * b_field_pol_probe_omv_channel             (b_field_pol_probe_omv_channel) <U11 132B ...
#   * b_field_tor_probe_cc_channel              (b_field_tor_probe_cc_channel) <U13 156B ...
#   * bes_channel                               (bes_channel) <U13 2kB 'xbt/cha...
# Data variables: (12/21)
#     greenwald_density                         (shot_id, time) float64 15MB na...
#     line_average_n_e                          (shot_id, time) float64 15MB na...
#     neutron_rates_total                       (shot_id, time) float64 15MB na...
#     power_radiated                            (shot_id, time) float64 15MB na...
#     b_field_pol_probe_ccbv_field              (shot_id, time, b_field_pol_probe_ccbv_channel) float64 598MB ...
#     b_field_pol_probe_obr_field               (shot_id, time, b_field_pol_probe_obr_channel) float64 269MB ...
#     ...                                        ...
#     solenoid_current                          (shot_id, time) float64 15MB na...
#     power_nbi                                 (shot_id, time) float64 15MB na...
#     b_field_pol_probe_cc_field                (shot_id, time, b_field_pol_probe_cc_channel) float64 75MB ...
#     b_field_pol_probe_omv_voltage             (shot_id, time, b_field_pol_probe_omv_channel) float64 45MB ...
#     b_field_tor_probe_cc_field                (shot_id, time, b_field_tor_probe_cc_channel) float64 45MB ...
#     filter_spectrometer_bes_voltage           (shot_id, time, bes_channel) float64 478MB ...
# Attributes:
#     description:

# %%
for var in ds.data_vars:
    print(f"Variable: {var}")
    print(ds[var].shape)
    print("===============")
# Out:
# Variable: greenwald_density
# (30, 62282)
# ===============
# Variable: line_average_n_e
# (30, 62282)
# ===============
# Variable: neutron_rates_total
# (30, 62282)
# ===============
# Variable: power_radiated
# (30, 62282)
# ===============
# Variable: b_field_pol_probe_ccbv_field
# (30, 62282, 40)
# ===============
# Variable: b_field_pol_probe_obr_field
# (30, 62282, 18)
# ===============
# Variable: b_field_pol_probe_obv_field
# (30, 62282, 18)
# ===============
# Variable: b_field_tor_probe_saddle_field
# (30, 62282, 12)
# ===============
# Variable: b_field_tor_probe_saddle_voltage
# (30, 62282, 12)
# ===============
# Variable: flux_loop_flux
# (30, 62282, 15)
# ===============
# Variable: ip
# (30, 62282)
# ===============
# Variable: density_gradient
# (30, 62282)
# ===============
# Variable: filter_spectrometer_dalpha_voltage
# (30, 62282, 3)
# ===============
# Variable: coil_current
# (30, 62282, 14)
# ===============
# Variable: coil_voltage
# (30, 62282, 14)
# ===============
# Variable: solenoid_current
# (30, 62282)
# ===============
# Variable: power_nbi
# (30, 62282)
# ===============
# Variable: b_field_pol_probe_cc_field
# (30, 62282, 5)
# ===============
# Variable: b_field_pol_probe_omv_voltage
# (30, 62282, 3)
# ===============
# Variable: b_field_tor_probe_cc_field
# (30, 62282, 3)
# ===============
# Variable: filter_spectrometer_bes_voltage
# (30, 62282, 32)
# ===============

# %%
ds["b_field_pol_probe_omv_voltage"].shape
# Out:
# (30, 62282, 3)

# %%
ds.close()
